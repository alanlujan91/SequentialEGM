# %%
from ConsLaborSeparableModel import LaborSeparableConsumerType
import numpy as np
from utilities import plot_warped_bilinear_flat
agent = LaborSeparableConsumerType(Disutility=False)
import matplotlib.pyplot as plt
from HARK.utilities import plot_funcs

# %%
plot_funcs(agent.solution_terminal.consumption_saving.vp_func, 0, 10)
# Out:
# c:\Users\alujan\mambaforge\envs\egmn-dev\lib\site-packages\HARK\rewards.py:66: RuntimeWarning: divide by zero encountered in power
#   return c**-rho

# %%
plot_warped_bilinear_flat(agent.solution_terminal.labor_leisure.c_func, 0, 2)

# %%
agent.solution_terminal.labor_leisure.c_func.values.max()
# Out:
# 80.00000000000003

# %%
agent.WageRte
# Out:
# [1.0]
